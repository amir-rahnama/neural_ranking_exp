# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import math
import logging
from scipy.stats import rankdata
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.sparse import csr_matrix
from scipy.stats import kendalltau
import time
import pickle
import shap
from tabulate import tabulate
from matplotlib.ticker import MaxNLocator
from generating_lirme_exs import random_exp
# Out:
# 2024-03-30 09:10:10.991096: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-30 09:10:11.308542: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-30 09:10:11.332400: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-03-30 09:10:11.332424: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-03-30 09:10:12.378942: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-30 09:10:12.379062: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-30 09:10:12.379072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
np.random.seed(42)

# %%
_name_features = [str(i + 1) for i in range(0, 100)]
df_test = pd.read_csv("./test_yahoo.csv")

# %%
def calculate_metrics(gam_explanations, lime_explanations, k_top):
    """Calculates the rbo and the overlap metrics for two set of explanations

    Args:
        gam_explanations: ndarray of subscores from GAM model
        lime_explanations: ndarray of subscores from LIME
    Returns:
       rbo (float) and overlap list (floats)
    """

    ranked_GAM = rankdata([-1 * i for i in gam_explanations], method='ordinal').astype(int) - 1
    ranked_LIME = rankdata([-1 * i for i in lime_explanations], method='ordinal').astype(int) - 1
    rbo_metric = rbo(ranked_GAM, ranked_LIME, k_top)
    overlap_metric = iter_overlap(ranked_GAM, ranked_LIME)
    
    return rbo_metric, overlap_metric
    
def rbo(list1, list2, p=0.9):
    """Calculates the rbo score for two equal sized ranks

    Args:
        list1: list of ranked values (integers)
        list2: list of ranked values (integers). Same length as list1
        p: weight assigned to items at different positions in the ranked lists, ranges [0,1]
    Returns:
       rbo (float)
    """
    # tail recursive helper function
    def helper(ret, i, d):
        l1 = set(list1[:i]) if i < len(list1) else set(list1)
        l2 = set(list2[:i]) if i < len(list2) else set(list2)
        a_d = len(l1.intersection(l2)) / i
        term = math.pow(p, i) * a_d
        if d == i:
            return ret + term
        return helper(ret + term, i + 1, d)

    k = max(len(list1), len(list2))
    x_k = len(set(list1).intersection(set(list2)))
    summation = helper(0, 1, k)

    return ((float(x_k) / k) * math.pow(p, k)) + ((1 - p) / p * summation)

def iter_overlap(list1, list2):
    """Calculates the % of overlap for two equal sized lists of ranked values in incremental sets
    of five, from 0 to number features

    Args:
        list1: list of ranked values (integers)
        list2: list of ranked values (integers). Same length as list1
    Returns:
       List of floats
    """
    list_overlap = []
    for x in range(5, len(_name_features) + 5, 5):
        included_values = [i for i in range(x)]
        indices1 = np.where(np.isin(list1, included_values))[0]
        indices2 = np.where(np.isin(list2, included_values))[0]
        inter = np.size(np.intersect1d(indices1, indices2))
        list_overlap.append(inter / x)
    return list_overlap

def get_auc(exp):
    #cutoffs = np.linspace(0.05, 0.45, 10)
    cutoffs = range(5, len(_name_features) + 5, 5)
    auc = {}
    temp = np.array(exp).mean(axis=1)
    auc_ = 0
    for k in range(1, len(cutoffs) - 1):
        x = cutoffs[k] - cutoffs[k - 1]
        y = temp[k] + temp[k-1]
        auc_ += y / ( 2 * x)
    return auc_

# %%
#std_features = df_test.std().iloc[2:].rank(ascending=False).values
std_features = df_test.std().iloc[2:].values

# %%
sample_sizes = [500, 1000, 2000, 3000, 5000]

eval_result = {}
for s_size in sample_sizes: 
    eval_result[s_size] = {f'overlap_{s_size}': {}, f'rbo_{s_size}': {}}#, f'corr_{s_size}': {}}

# %%
exp_names = ['lirme', 'exs_top_k', 'top_k_rank', 'exs_score', 'lime', 'shap', 'top_k_rank', 'random']

# %%
all_exps = {}

for s_size in sample_sizes[:-1]: 
    all_exps[s_size] = {}
    laura_exps = pickle.load( open( f"laura_exps_{s_size}_v2_rank_2.p", "rb" ) )
    our_exps = pickle.load( open( f"p_exps_{s_size}_v2_ranked_2.p", "rb" ) )
    
    queries_list = list(our_exps.keys())
    
    for k in laura_exps[s_size].keys(): 
        if k not in all_exps.keys():
            all_exps[s_size][k] = []
        all_exps[s_size][k] =  laura_exps[s_size][k]['exp']
    
    for k in exp_names: 
        if k not in all_exps.keys():
            all_exps[s_size][k] = []
                
        for q in queries_list:
            if k == 'random':
                all_exps[s_size][k].append(random_exp(len(_name_features)))
            else: 
                all_exps[s_size][k].append(our_exps[q][k])

# %%
all_gt = []
    
for i in range(len(laura_exps[s_size]['gaussian']['gt'])):
    all_gt.append(laura_exps[s_size]['gaussian']['gt'][i])

# %%
#our_exps = pickle.load( open( f"p_exps_500_v2.p", "rb" ) )

# %%
queries = [28587, 23068, 28700, 24240, 23890, 28483, 23132, 29379, 23022, 24923, 25000, 29889, 25191, 25207, 25226, 28035, 28203, 28670, 28286, 28276]

# %%
def normalize(v):
    epsilon = np.finfo(np.float32).eps
    sum_v = np.sum(v) 
    return v / (sum_v + epsilon)

# %%
eval_result = {}

for s_size in all_exps.keys():
    #print(s_size)
    eval_result[s_size] = {f'rbo_{s_size}': {}, f'overlap_{s_size}': {}}
    for e in all_exps[s_size].keys():
        temp_overlap = []
        temp_rbo = []
        
        for i in range(len(all_exps[s_size][e])): 
            exp_val = all_exps[s_size][e][i].reshape(len(_name_features))
            gt_val = all_gt[i].reshape(len(_name_features))
            rbo_m, overlap_m = calculate_metrics(normalize(gt_val), normalize(exp_val), 0.95)
            temp_rbo.append(rbo_m)
            temp_overlap.append(overlap_m)
        
        eval_result[s_size][f'rbo_{s_size}'][e] = np.mean(temp_rbo) 
        eval_result[s_size][f'overlap_{s_size}'][e] =  get_auc(np.array(temp_overlap))

# %% [markdown]
# final_result = pd.concat([pd.DataFrame(eval_result[500]),
#            pd.DataFrame(eval_result[1000]),
#            pd.DataFrame(eval_result[2000]),
#            pd.DataFrame(eval_result[3000]),
#            pd.DataFrame(eval_result[5000])], axis=1)

# %%
final_result = pd.concat([pd.DataFrame(eval_result[500]), 
           pd.DataFrame(eval_result[1000]),
           pd.DataFrame(eval_result[2000]),
           pd.DataFrame(eval_result[3000])], axis=1)

# %%
final_result.round(2).style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_919dd_row1_col1, #T_919dd_row1_col3, #T_919dd_row1_col5, #T_919dd_row2_col1, #T_919dd_row2_col3, #T_919dd_row2_col7, #T_919dd_row3_col0, #T_919dd_row4_col2, #T_919dd_row4_col6, #T_919dd_row7_col4, #T_919dd_row7_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_919dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_919dd_level0_col0" class="col_heading level0 col0" >rbo_500</th>
#       <th id="T_919dd_level0_col1" class="col_heading level0 col1" >overlap_500</th>
#       <th id="T_919dd_level0_col2" class="col_heading level0 col2" >rbo_1000</th>
#       <th id="T_919dd_level0_col3" class="col_heading level0 col3" >overlap_1000</th>
#       <th id="T_919dd_level0_col4" class="col_heading level0 col4" >rbo_2000</th>
#       <th id="T_919dd_level0_col5" class="col_heading level0 col5" >overlap_2000</th>
#       <th id="T_919dd_level0_col6" class="col_heading level0 col6" >rbo_3000</th>
#       <th id="T_919dd_level0_col7" class="col_heading level0 col7" >overlap_3000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_919dd_level0_row0" class="row_heading level0 row0" >smote</th>
#       <td id="T_919dd_row0_col0" class="data row0 col0" >0.190000</td>
#       <td id="T_919dd_row0_col1" class="data row0 col1" >2.050000</td>
#       <td id="T_919dd_row0_col2" class="data row0 col2" >0.210000</td>
#       <td id="T_919dd_row0_col3" class="data row0 col3" >2.140000</td>
#       <td id="T_919dd_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_919dd_row0_col5" class="data row0 col5" >2.120000</td>
#       <td id="T_919dd_row0_col6" class="data row0 col6" >0.200000</td>
#       <td id="T_919dd_row0_col7" class="data row0 col7" >2.140000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row1" class="row_heading level0 row1" >gaussian</th>
#       <td id="T_919dd_row1_col0" class="data row1 col0" >0.220000</td>
#       <td id="T_919dd_row1_col1" class="data row1 col1" >2.360000</td>
#       <td id="T_919dd_row1_col2" class="data row1 col2" >0.210000</td>
#       <td id="T_919dd_row1_col3" class="data row1 col3" >2.410000</td>
#       <td id="T_919dd_row1_col4" class="data row1 col4" >0.200000</td>
#       <td id="T_919dd_row1_col5" class="data row1 col5" >2.440000</td>
#       <td id="T_919dd_row1_col6" class="data row1 col6" >0.180000</td>
#       <td id="T_919dd_row1_col7" class="data row1 col7" >2.430000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row2" class="row_heading level0 row2" >lhs</th>
#       <td id="T_919dd_row2_col0" class="data row2 col0" >0.200000</td>
#       <td id="T_919dd_row2_col1" class="data row2 col1" >2.360000</td>
#       <td id="T_919dd_row2_col2" class="data row2 col2" >0.200000</td>
#       <td id="T_919dd_row2_col3" class="data row2 col3" >2.410000</td>
#       <td id="T_919dd_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_919dd_row2_col5" class="data row2 col5" >2.430000</td>
#       <td id="T_919dd_row2_col6" class="data row2 col6" >0.210000</td>
#       <td id="T_919dd_row2_col7" class="data row2 col7" >2.440000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row3" class="row_heading level0 row3" >dlime</th>
#       <td id="T_919dd_row3_col0" class="data row3 col0" >0.230000</td>
#       <td id="T_919dd_row3_col1" class="data row3 col1" >2.260000</td>
#       <td id="T_919dd_row3_col2" class="data row3 col2" >0.220000</td>
#       <td id="T_919dd_row3_col3" class="data row3 col3" >2.360000</td>
#       <td id="T_919dd_row3_col4" class="data row3 col4" >0.220000</td>
#       <td id="T_919dd_row3_col5" class="data row3 col5" >2.390000</td>
#       <td id="T_919dd_row3_col6" class="data row3 col6" >0.190000</td>
#       <td id="T_919dd_row3_col7" class="data row3 col7" >2.430000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row4" class="row_heading level0 row4" >lirme</th>
#       <td id="T_919dd_row4_col0" class="data row4 col0" >0.200000</td>
#       <td id="T_919dd_row4_col1" class="data row4 col1" >1.990000</td>
#       <td id="T_919dd_row4_col2" class="data row4 col2" >0.230000</td>
#       <td id="T_919dd_row4_col3" class="data row4 col3" >1.980000</td>
#       <td id="T_919dd_row4_col4" class="data row4 col4" >0.200000</td>
#       <td id="T_919dd_row4_col5" class="data row4 col5" >1.980000</td>
#       <td id="T_919dd_row4_col6" class="data row4 col6" >0.220000</td>
#       <td id="T_919dd_row4_col7" class="data row4 col7" >1.980000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row5" class="row_heading level0 row5" >exs_top_k</th>
#       <td id="T_919dd_row5_col0" class="data row5 col0" >0.190000</td>
#       <td id="T_919dd_row5_col1" class="data row5 col1" >1.930000</td>
#       <td id="T_919dd_row5_col2" class="data row5 col2" >0.200000</td>
#       <td id="T_919dd_row5_col3" class="data row5 col3" >1.920000</td>
#       <td id="T_919dd_row5_col4" class="data row5 col4" >0.180000</td>
#       <td id="T_919dd_row5_col5" class="data row5 col5" >1.920000</td>
#       <td id="T_919dd_row5_col6" class="data row5 col6" >0.180000</td>
#       <td id="T_919dd_row5_col7" class="data row5 col7" >1.920000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row6" class="row_heading level0 row6" >top_k_rank</th>
#       <td id="T_919dd_row6_col0" class="data row6 col0" >0.200000</td>
#       <td id="T_919dd_row6_col1" class="data row6 col1" >1.930000</td>
#       <td id="T_919dd_row6_col2" class="data row6 col2" >0.210000</td>
#       <td id="T_919dd_row6_col3" class="data row6 col3" >1.960000</td>
#       <td id="T_919dd_row6_col4" class="data row6 col4" >0.210000</td>
#       <td id="T_919dd_row6_col5" class="data row6 col5" >1.960000</td>
#       <td id="T_919dd_row6_col6" class="data row6 col6" >0.200000</td>
#       <td id="T_919dd_row6_col7" class="data row6 col7" >1.890000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row7" class="row_heading level0 row7" >exs_score</th>
#       <td id="T_919dd_row7_col0" class="data row7 col0" >0.180000</td>
#       <td id="T_919dd_row7_col1" class="data row7 col1" >1.990000</td>
#       <td id="T_919dd_row7_col2" class="data row7 col2" >0.190000</td>
#       <td id="T_919dd_row7_col3" class="data row7 col3" >1.980000</td>
#       <td id="T_919dd_row7_col4" class="data row7 col4" >0.240000</td>
#       <td id="T_919dd_row7_col5" class="data row7 col5" >1.970000</td>
#       <td id="T_919dd_row7_col6" class="data row7 col6" >0.220000</td>
#       <td id="T_919dd_row7_col7" class="data row7 col7" >1.980000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row8" class="row_heading level0 row8" >lime</th>
#       <td id="T_919dd_row8_col0" class="data row8 col0" >0.200000</td>
#       <td id="T_919dd_row8_col1" class="data row8 col1" >1.920000</td>
#       <td id="T_919dd_row8_col2" class="data row8 col2" >0.190000</td>
#       <td id="T_919dd_row8_col3" class="data row8 col3" >1.950000</td>
#       <td id="T_919dd_row8_col4" class="data row8 col4" >0.220000</td>
#       <td id="T_919dd_row8_col5" class="data row8 col5" >1.950000</td>
#       <td id="T_919dd_row8_col6" class="data row8 col6" >0.190000</td>
#       <td id="T_919dd_row8_col7" class="data row8 col7" >1.950000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row9" class="row_heading level0 row9" >shap</th>
#       <td id="T_919dd_row9_col0" class="data row9 col0" >0.200000</td>
#       <td id="T_919dd_row9_col1" class="data row9 col1" >1.960000</td>
#       <td id="T_919dd_row9_col2" class="data row9 col2" >0.200000</td>
#       <td id="T_919dd_row9_col3" class="data row9 col3" >1.960000</td>
#       <td id="T_919dd_row9_col4" class="data row9 col4" >0.200000</td>
#       <td id="T_919dd_row9_col5" class="data row9 col5" >1.960000</td>
#       <td id="T_919dd_row9_col6" class="data row9 col6" >0.200000</td>
#       <td id="T_919dd_row9_col7" class="data row9 col7" >1.960000</td>
#     </tr>
#     <tr>
#       <th id="T_919dd_level0_row10" class="row_heading level0 row10" >random</th>
#       <td id="T_919dd_row10_col0" class="data row10 col0" >0.190000</td>
#       <td id="T_919dd_row10_col1" class="data row10 col1" >1.910000</td>
#       <td id="T_919dd_

# %%
all_exp_names = list(final_result.index)

# %%
print(tabulate(final_result.T.round(2), tablefmt='latex_raw'))
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \hline
#  rbo_500      & 0.19 & 0.22 & 0.2  & 0.23 & 0.2  & 0.19 & 0.2  & 0.18 & 0.2  & 0.2  & 0.19 \\
#  overlap_500  & 2.05 & 2.36 & 2.36 & 2.26 & 1.99 & 1.93 & 1.93 & 1.99 & 1.92 & 1.96 & 1.91 \\
#  rbo_1000     & 0.21 & 0.21 & 0.2  & 0.22 & 0.23 & 0.2  & 0.21 & 0.19 & 0.19 & 0.2  & 0.19 \\
#  overlap_1000 & 2.14 & 2.41 & 2.41 & 2.36 & 1.98 & 1.92 & 1.96 & 1.98 & 1.95 & 1.96 & 1.92 \\
#  rbo_2000     & 0.2  & 0.2  & 0.2  & 0.22 & 0.2  & 0.18 & 0.21 & 0.24 & 0.22 & 0.2  & 0.19 \\
#  overlap_2000 & 2.12 & 2.44 & 2.43 & 2.39 & 1.98 & 1.92 & 1.96 & 1.97 & 1.95 & 1.96 & 1.87 \\
#  rbo_3000     & 0.2  & 0.18 & 0.21 & 0.19 & 0.22 & 0.18 & 0.2  & 0.22 & 0.19 & 0.2  & 0.2  \\
#  overlap_3000 & 2.14 & 2.43 & 2.44 & 2.43 & 1.98 & 1.92 & 1.89 & 1.98 & 1.95 & 1.96 & 1.9  \\
# \hline
# \end{tabular}

# %%
exp_name_figure = {
    'smote': 'Smote',
     'gaussian':'Gaussian',
     'lhs': 'LHS',
     'dlime': 'DLIME',
     'lirme': 'LIRME',
     'exs_top_k': 'EXS (B)',
     'top_k_rank': 'EXS (R)',
     'exs_score': 'EXS (S)',
     'lime': 'LIME',
     'shap': 'SHAP',
     'random': 'Random'
}

# %%
exp_color_figure = {
    'smote': 'blue',
     'gaussian':'orange',
     'lhs': 'green',
     'dlime': 'red',
     'lirme': 'purple',
     'exs_top_k': 'brown',
     'top_k_rank': 'pink',
     'exs_score': 'gray',
     'lime': 'olive',
     'shap': 'cyan',
     'random': 'black'
}

# %%
def process_ax(ax):
    for axis in ['bottom', 'left']:
        ax.spines[axis].set_linewidth(2.5)
        ax.spines[axis].set_color('0.2')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    ax.tick_params(width = 2.5, color = '0.2')

    ax.set_xlabel(ax.get_xlabel(), fontsize = 15, weight = 'bold', color = '0.2')
    ax.set_ylabel(ax.get_ylabel(), fontsize = 15, weight = 'bold', color = '0.2')

    return ax

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 4), dpi=400, sharey=True, sharex=True)

x_range = range(5, len(_name_features) + 5, 5)

sam_size = [500, 2000]
    
for k in range(len(sam_size)):
    s_size = sam_size[k]
    for e in all_exps[s_size].keys(): 
        temp_overlap = []
        for i in range(len(all_exps[s_size][e])): 
            exp_val = all_exps[s_size][e][i]
            gt_val = all_gt[i]
            #_, overlap_m = calculate_metrics(gt_val, exp_val, 0.95)
            _, overlap_m = calculate_metrics(normalize(gt_val), normalize(exp_val), 0.95)
            #temp_corr.append(kendalltau(std_features, exp_val))
            temp_overlap.append(overlap_m)
        if e == 'random': 
            linestyle = 'dashed'
        else:
            linestyle = 'solid'
        ax[k].plot(x_range, np.array(temp_overlap).mean(axis=0), label=exp_name_figure[e], c=exp_color_figure[e], linestyle=linestyle)
        ax[k].set_xlabel(r'Top-$K$ Features', fontsize=20)
        ax[k].set_ylabel(r'OverLap', fontsize=20)
        ax[k].set_title(f'Sample Size: {s_size}', fontsize=20, fontweight='bold')
        ax[k] = process_ax(ax[k])
ax[1].legend(bbox_to_anchor=(1.1, 1), prop={'size': 10})
#eval_result[s_size][f'rbo_{s_size}'][e] = np.nanmean(temp_rbo)
#eval_result[s_size][f'overlap_{s_size}'][e] = np.nanmean(temp_overlap)
plt.tight_layout()
plt.savefig('./overlap_example_rank_2.pdf')
plt.show()

# %% [markdown]
# ### Questions: What features are usually in ground truth but don't get a lot of importance in the explanations?

# %%
top_k = 10

gt_freq = np.zeros(len(_name_features))

for i in range(len(all_gt)):
    gt_val = all_gt[i]
    sel_feat_gt = np.argsort(np.abs(gt_val))[::-1][:top_k]
    gt_freq[sel_feat_gt] += 1

# %%
exp_freq = {}

for e in all_exps[s_size].keys(): 
    freq = np.zeros(len(_name_features))
    
    for i in range(len(all_exps[s_size][e])): 
        exp_val = all_exps[s_size][e][i]
        sel_feat = np.argsort(np.abs(exp_val))[::-1][:top_k]
        freq[sel_feat] += 1

    gt_max_idx = np.argsort(np.abs(freq))[::-1][:top_k]
    val_freq = freq[gt_max_idx]
    
    exp_freq[e] = {'key_feat': gt_max_idx, 'val_freq': val_freq}

# %%
# TODO: Add random and GT here
fig, ax = plt.subplots(2, 6, figsize=(20, 11), sharey=True)
ax = ax.ravel()

for i in range(len(all_exp_names)):
    e = exp_freq[all_exp_names[i]]
    x_axis = np.arange(len(e['key_feat']))

    ax[i].bar(x_axis, e['val_freq'])
    ax[i].set_xticklabels(e['key_feat'], rotation=90)
    ax[i].set_xticks(np.arange(len(x_axis)))
    ax[i].set_title(exp_name_figure[all_exp_names[i]],  fontsize=12, fontweight='bold')
    #ax[i].set_yticklabels(np.arange(0, 20, 4), rotation=90)
    #ax[i].set_yticks(np.arange(5))
    ax[i].yaxis.set_major_locator(MaxNLocator(integer=True))
    ax[i] = process_ax(ax[i])

gt_max_idx = np.argsort(np.abs(gt_freq))[::-1][:top_k]
val_freq = gt_freq[gt_max_idx]
x_axis = np.arange(len(gt_max_idx))

ax[-1].bar(x_axis, val_freq)
ax[-1].set_xticklabels(gt_max_idx, rotation=90)
ax[-1].set_xticks(np.arange(len(gt_max_idx)))
ax[-1].set_title('Ground Truth',  fontsize=15, fontweight='bold')
ax[-1].yaxis.set_major_locator(MaxNLocator(integer=True))
ax[-1] = process_ax(ax[-1])


ax[0].set_ylabel('Frequency')
ax[6].set_ylabel('Frequency')

for i in range(6, 12):
    ax[i].set_xlabel('Features')

plt.tight_layout()
plt.savefig('./top_10_important_features_rank_2.pdf')
# Out:
# FixedFormatter should only be used together with FixedLocator
# FixedFormatter should only be used together with FixedLocator

# %%
### Overlap between importnat features

# %%
all_exps_rank_10 = {}

for s_size in sample_sizes: 
    all_exps_rank_10[s_size] = {}
    laura_exps = pickle.load( open( f"./result/laura_exps_{s_size}_v3.p", "rb" ) )
    our_exps = pickle.load( open( f"./result/p_exps_{s_size}_v2.p", "rb" ) )
    
    queries_list = list(our_exps.keys())
    
    for k in laura_exps[s_size].keys(): 
        if k not in all_exps.keys():
            all_exps_rank_10[s_size][k] = []
        all_exps_rank_10[s_size][k] =  laura_exps[s_size][k]['exp']
    
    for k in exp_names: 
        if k not in all_exps.keys():
            all_exps_rank_10[s_size][k] = []
                
        for q in queries_list:
            if k == 'random':
                all_exps_rank_10[s_size][k].append(random_exp(len(_name_features)))
            else: 
                all_exps_rank_10[s_size][k].append(our_exps[q][k])

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 4), dpi=400, sharey=True, sharex=True)

x_range = range(5, len(_name_features) + 5, 5)

sam_size = [500, 2000]
    
for k in range(len(sam_size)):
    s_size = sam_size[k]
    for e in all_exps[s_size].keys(): 
        temp_overlap = []
        for i in range(len(all_exps[s_size][e])): 
            exp_val_1 = all_exps[s_size][e][i]
            exp_val_2 = all_exps_rank_10[s_size][e][i]
            #print(exp_val_1.shape,exp_val_2.shape) 
            #_, overlap_m = calculate_metrics(gt_val, exp_val, 0.95)
            _, overlap_m = calculate_metrics(exp_val_1, exp_val_2, 0.95)
            #temp_overlap.append(kendalltau(exp_val_1, exp_val_2))
            temp_overlap.append(overlap_m)
        if e == 'random': 
            linestyle = 'dashed'
        else:
            linestyle = 'solid'
        ax[k].plot(x_range, np.array(temp_overlap).mean(axis=0), label=exp_name_figure[e], c=exp_color_figure[e], linestyle=linestyle)
        ax[k].set_xlabel(r'Top-$K$ Features', fontsize=20)
        ax[k].set_ylabel(r'OverLap', fontsize=20)
        ax[k].set_title(f'Sample Size: {s_size}', fontsize=20, fontweight='bold')
        ax[k] = process_ax(ax[k])
ax[1].legend(bbox_to_anchor=(1.1, 1), prop={'size': 10})
#eval_result[s_size][f'rbo_{s_size}'][e] = np.nanmean(temp_rbo)
#eval_result[s_size][f'overlap_{s_size}'][e] = np.nanmean(temp_overlap)
plt.tight_layout()
plt.savefig('./overlap_example_rank_2_10.pdf')
plt.show()
